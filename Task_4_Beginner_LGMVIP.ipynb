# %% [markdown]
# <a href="https://colab.research.google.com/github/Archana10siva/LGMVIP-DataScience/blob/main/Task_4_Beginner_LGMVIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LETS GROW MORE**
#
# Data Science Internship (LGMVIP-September 2021)
#
# **Level -** Beginner
#
# **TASK 4 :** IMAGE TO PENCIL SKETCH USING PYTHON
#
# **AUTHOR :** ARCHANA SIVAPRASAD

# %% [markdown]
# **IMPORTING REQUIRED LIBRARIES**

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
def show(title,img,cmap='RdBu'):
    plt.imshow(img,cmap=cmap)
    plt.title(title)

# %% [markdown]
#  **READING THE IMAGE**

# %%
image=plt.imread("Kitten.jfif")
show("Kitten",image,'RdBu')

# %% [markdown]
# **CONVERTING IMAGE INTO GRAYSCALE IMAGE**

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
show("gray_image",gray_image,'gray')

# %% [markdown]
# **INVERT THE GRAYSCALE IMAGE**

# %%
inverted_image =255-gray_image
show("inverted_image",inverted_image,'gray')

# %% [markdown]
# **BLUR THE INVERTED IMAGE**

# %%
blurred_image =cv2.GaussianBlur(inverted_image,(21,21),0)
show("blurred_image",blurred_image,'gray')

# %% [markdown]
# **INVERTING THE BLURRED IMAGE**

# %%
inverted_blurred_image = 255 - blurred_image
show("inverted_blurred_image",inverted_blurred_image,'gray')

# %% [markdown]
# **CREATE PENCIL SKETCH IMAGE**

# %%
pencil_sketch=cv2.divide(gray_image,inverted_blurred_image,scale=256.0)
show("pencil_sketch",pencil_sketch,'gray')

# %% [markdown]
# **CONCLUSION**
#
# Converted an RGB image into a pencil sketch.

# %% [markdown]
# ### **THANKYOU!!!**
